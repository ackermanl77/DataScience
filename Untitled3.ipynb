# %%
import pandas as pd
import math
import numpy as np

# %%
tabla = pd.read_csv('TR_PERSONA09.CSV',encoding='latin1')
tabla.head()
# Out:
#         ID_VIV     ID_PERSONA  ENT           NOM_ENT  MUN       NOM_MUN  \
# 0  90020000001  9002000000101    9  Distrito Federal    2  Azcapotzalco
# 1  90020000001  9002000000102    9  Distrito Federal    2  Azcapotzalco
# 2  90020000002  9002000000201    9  Distrito Federal    2  Azcapotzalco
# 3  90020000003  9002000000306    9  Distrito Federal    2  Azcapotzalco
# 4  90020000003  9002000000305    9  Distrito Federal    2  Azcapotzalco
#
#    LOC50K       NOM_LOC  COBERTURA    ESTRATO  ...  HIJOS_NAC_VIVOS  \
# 0       1  Azcapotzalco          2  09-002-02  ...              NaN
# 1       1  Azcapotzalco          2  09-002-02  ...              NaN
# 2       1  Azcapotzalco          2  09-002-03  ...              5.0
# 3       1  Azcapotzalco          2  09-002-02  ...              NaN
# 4       1  Azcapotzalco          2  09-002-02  ...              NaN
#
#    HIJOS_FALLECIDOS  HIJOS_SOBREVIV  FECHA_NAC_M  FECHA_NAC_A  SOBREVIVENCIA  \
# ...

# %%
Trues = tabla['NOM_MUN']=='Coyoacan'

# %%
sum(Trues)
# Out:
# 0

# %%
tabla1 = pd.read_csv('TR_PERSONA15.CSV',encoding='latin1')
tabla1.head()
# Out:
#          ID_VIV      ID_PERSONA  ENT NOM_ENT  MUN                    NOM_MUN  \
# 0  150010000001  15001000000105   15  México    1  Acambay de Ruíz Castañeda
# 1  150010000001  15001000000101   15  México    1  Acambay de Ruíz Castañeda
# 2  150010000001  15001000000102   15  México    1  Acambay de Ruíz Castañeda
# 3  150010000001  15001000000103   15  México    1  Acambay de Ruíz Castañeda
# 4  150010000001  15001000000104   15  México    1  Acambay de Ruíz Castañeda
#
#    LOC50K                                  NOM_LOC  COBERTURA    ESTRATO  ...  \
# 0       0  Localidad de menos de 50 mil habitantes          2  15-001-09  ...
# 1       0  Localidad de menos de 50 mil habitantes          2  15-001-09  ...
# 2       0  Localidad de menos de 50 mil habitantes          2  15-001-09  ...
# 3       0  Localidad de menos de 50 mil habitantes          2  15-001-09  ...
# 4       0  Localidad de menos de 50 mil habitantes          2  15-001-09  ...
#
# ...
