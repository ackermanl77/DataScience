# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users//MELEJ//Documents//Mario Abarca//Ciencia de Datos//Datos//datos_abiertos_covid19//200421COVID19MEXICO.csv",encoding='latin1')
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2020-04-21      09e8dc       2       9          15     1
# 1          2020-04-21      1dd782       2      12           9     1
# 2          2020-04-21      0efbaf       2       9          28     2
# 3          2020-04-21      013a6c      99       3          15     2
# 4          2020-04-21      091a48       1      12          15     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... CARDIOVASCULAR  \
# 0           15           15             37              2  ...              2
# 1           15            9              3              1  ...              2
# 2           16           28             32              1  ...              2
# 3           15           15            106              1  ...              2
# 4           15           15             31              2  ...              2
#
#   OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51634 entries, 0 to 51633
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FECHA_ACTUALIZACION  51634 non-null  object
#  1   ID_REGISTRO          51634 non-null  object
#  2   ORIGEN               51634 non-null  int64
#  3   SECTOR               51634 non-null  int64
#  4   ENTIDAD_UM           51634 non-null  int64
#  5   SEXO                 51634 non-null  int64
#  6   ENTIDAD_NAC          51634 non-null  int64
#  7   ENTIDAD_RES          51634 non-null  int64
#  8   MUNICIPIO_RES        51634 non-null  int64
#  9   TIPO_PACIENTE        51634 non-null  int64
#  10  FECHA_INGRESO        51634 non-null  object
#  11  FECHA_SINTOMAS       51634 non-null  object
#  12  FECHA_DEF            51634 non-null  object
#  13  INTUBADO             51634 non-null  int64
#  14  NEUMONIA             51634 non-null  int64
# ...

# %%
df_crecimiento = df[["FECHA_ACTUALIZACION", "ORIGEN", "ENTIDAD_UM", "SEXO", "ENTIDAD_RES", "MUNICIPIO_RES", "TIPO_PACIENTE", "EDAD"]]
df_crecimiento.head()
# Out:
#   FECHA_ACTUALIZACION  ORIGEN  ENTIDAD_UM  SEXO  ENTIDAD_RES  MUNICIPIO_RES  \
# 0          2020-04-21       2          15     1           15             37
# 1          2020-04-21       2           9     1            9              3
# 2          2020-04-21       2          28     2           28             32
# 3          2020-04-21      99          15     2           15            106
# 4          2020-04-21       1          15     2           15             31
#
#    TIPO_PACIENTE  EDAD
# 0              2    75
# 1              1    31
# 2              1    22
# 3              1    26
# 4              2    50

# %%
df_fechas = df[["FECHA_ACTUALIZACION", "SEXO", "FECHA_INGRESO", "FECHA_SINTOMAS"]]
df_fechas.head()
# Out:
#   FECHA_ACTUALIZACION  SEXO FECHA_INGRESO FECHA_SINTOMAS
# 0          2020-04-21     1    2020-04-09     2020-03-28
# 1          2020-04-21     1    2020-04-16     2020-04-02
# 2          2020-04-21     2    2020-04-06     2020-04-04
# 3          2020-04-21     2    2020-04-16     2020-04-14
# 4          2020-04-21     2    2020-04-06     2020-04-04

# %%
df_padecimientos = df[[ "SEXO", "INTUBADO", "NEUMONIA", "EDAD", "EMBARAZO", "DIABETES", "EPOC", "ASMA", "INMUSUPR", "HIPERTENSION", "CARDIOVASCULAR", "OBESIDAD", "RENAL_CRONICA", "TABAQUISMO"]]
df_padecimientos.head()
# Out:
#    SEXO  INTUBADO  NEUMONIA  EDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  \
# 0     1         2         1    75         2         1     2     2         2
# 1     1        97         2    31         2         2     2     2         2
# 2     2        97         2    22        97         2     2     2         2
# 3     2        97         2    26        97         2     2     2         2
# 4     2         2         1    50        97         2     2     2         2
#
#    HIPERTENSION  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO
# 0             2               2         2              2           2
# 1             2               2         1              2           2
# 2             2               2         2              2           2
# 3             2               2         1              2           2
# 4             2               2         2              2           2

# %%
edades_hombres = df[df['SEXO'] == 1]['EDAD'].dropna()
edades_mujeres = df[df['SEXO'] == 2]['EDAD'].dropna()
plt.hist([edades_hombres, edades_mujeres],
         stacked=True, color=['blue', 'red'])
# Out:
# ([array([1.057e+03, 2.014e+03, 7.807e+03, 6.884e+03, 4.780e+03, 2.225e+03,
#          9.610e+02, 3.240e+02, 2.600e+01, 3.000e+00]),
#   array([2.2850e+03, 3.8870e+03, 1.4878e+04, 1.3413e+04, 9.4350e+03,
#          4.8430e+03, 2.1830e+03, 6.6000e+02, 4.7000e+01, 3.0000e+00])],
#  array([  0.,  12.,  24.,  36.,  48.,  60.,  72.,  84.,  96., 108., 120.]),
#  <a list of 2 Lists of Patches objects>)

# %%
labels = '2', '1'
datos = [np.sum(df['SEXO'] == 2), np.sum(df['SEXO'] == 1)]
plt.pie(datos, labels=labels, colors=['tomato', 'slateblue'],
        autopct='%1.1f %%')
plt.show()
